# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv')
df.head()
# Out:
#       ID           artist_name            track_name                track_id  \
# 0   1770            Neon Trees       Everybody Talks  2iUmqdfGZcHIhS3b9E9EWq
# 1   1771              Deftones              Rosemary  4FEr6dIdH6EqLKR0jB560J
# 2   1773  Thousand Foot Krutch         Courtesy Call  0AOmbw8AwDnwXhHC3OhdVB
# 3   1816             Vicentico   No Te Apartes de Mí  74KqkyHbpneHF6JT8EwUOO
# 4  12104            Bruno Mars  Locked out of Heaven  3w3y8KPTfNeOKPiqUTakBh
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          77  2012  alt-rock         0.471   0.924    8    -3.906     1
# 1          71  2012  alt-rock         0.285   0.613    5    -6.412     1
# 2          71  2012  alt-rock         0.531   0.638   11    -5.145     0
# 3          70  2012  alt-rock         0.816   0.549    7    -8.649     1
# 4          85  2012     dance         0.726   0.698    5    -4.165     1
#
# ...

# %%
df_clean = df.drop(['track_id', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'duration_ms', 'time_signature'], axis=1)
df_clean.head()
# Out:
#       ID           artist_name            track_name  popularity  year  \
# 0   1770            Neon Trees       Everybody Talks          77  2012
# 1   1771              Deftones              Rosemary          71  2012
# 2   1773  Thousand Foot Krutch         Courtesy Call          71  2012
# 3   1816             Vicentico   No Te Apartes de Mí          70  2012
# 4  12104            Bruno Mars  Locked out of Heaven          85  2012
#
#       genre  danceability  energy  key  valence    tempo
# 0  alt-rock         0.471   0.924    8   0.7250  154.961
# 1  alt-rock         0.285   0.613    5   0.0772  126.628
# 2  alt-rock         0.531   0.638   11   0.4450  164.079
# 3  alt-rock         0.816   0.549    7   0.8860  111.032
# 4     dance         0.726   0.698    5   0.8670  143.994

# %%
df = df_clean.groupby(['year', 'genre'])
df.head(50)
# Out:
#            ID           artist_name                track_name  popularity  \
# 0        1770            Neon Trees           Everybody Talks          77
# 1        1771              Deftones                  Rosemary          71
# 2        1773  Thousand Foot Krutch             Courtesy Call          71
# 3        1816             Vicentico       No Te Apartes de Mí          70
# 4       12104            Bruno Mars      Locked out of Heaven          85
# ...       ...                   ...                       ...         ...
# 3313  1296636              Kid Cudi  Day 'N' Nite (nightmare)          70
# 3314  1296637                 Drake                   Forever          72
# 3315  1296645                Eminem            Crack A Bottle          70
# 3316  1296647                Eminem                 Beautiful          70
# 3317  1296748            Imran Khan                    Bewafa          70
#
#       year     genre  danceability  energy  key  valence    tempo
# ...

# %%
df.to_csv('cleanData.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.to_csv('cleanData.csv')
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'
