# %%
import sqlite3 as sq
import pandas as pd

# %%
df = pd.read_csv("static\spotify_data_short.csv")
df_clean = df.drop(columns=df.columns[0], axis=1, inplace=True)
df.columns = df.columns.str.strip()
df.head()
# Out:
#             artist_name            track_name                track_id  \
# 0            Neon Trees       Everybody Talks  2iUmqdfGZcHIhS3b9E9EWq
# 1              Deftones              Rosemary  4FEr6dIdH6EqLKR0jB560J
# 2  Thousand Foot Krutch         Courtesy Call  0AOmbw8AwDnwXhHC3OhdVB
# 3             Vicentico   No Te Apartes de Mí  74KqkyHbpneHF6JT8EwUOO
# 4            Bruno Mars  Locked out of Heaven  3w3y8KPTfNeOKPiqUTakBh
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          77  2012  alt-rock         0.471   0.924    8    -3.906     1
# 1          71  2012  alt-rock         0.285   0.613    5    -6.412     1
# 2          71  2012  alt-rock         0.531   0.638   11    -5.145     0
# 3          70  2012  alt-rock         0.816   0.549    7    -8.649     1
# 4          85  2012     dance         0.726   0.698    5    -4.165     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
conn = sq.connect("Spoofify.db")
cur = conn.cursor()

# %%
df.to_sql("Spotify_DB", conn, if_exists="replace")
# Out:
# 1159764

# %%
cur.close()
conn.close()
